# %%
import pycaret
import pandas as pd
from pycaret.regression import *
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use(['seaborn'])
from sklearn import set_config
set_config(display='text')

# %%
df = pd.read_csv('fatigue_pycaret.csv')  # features are standardised and fatigue life in log-scale

# %%
df
# Out:
#      No of cycles(log-scaled)  fatigue stress(strength) (MPa)  \
# 0                    1.934498                        1.660370
# 1                    2.008600                       -0.138214
# 2                    2.012837                        0.048208
# 3                    2.012837                       -0.069141
# 4                    2.012837                       -0.015031
# 5                    2.012837                       -0.307462
# 6                    2.064458                        0.930535
# 7                    2.155336                        1.630210
# 8                    2.170262                        0.920231
# 9                    2.173186                        1.003840
# 10                   2.238046                        1.037910
# 11                   2.260071                        1.621360
# 12                   2.320146                        0.958673
# 13                   2.324282                        1.037340
# ...

# %%
# setup the dataset
grid = setup(data=df, target='No of cycles(log-scaled)',session_id=245, train_size=0.9)
# Out:
# <style type="text/css">
# #T_14a3d_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_14a3d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14a3d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_14a3d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14a3d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14a3d_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_14a3d_row0_col1" class="data row0 col1" >245</td>
#     </tr>
#     <tr>
#       <th id="T_14a3d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_14a3d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_14a3d_row1_col1" class="data row1 col1" >No of cycles(log-scaled)</td>
#     </tr>
#     <tr>
#       <th id="T_14a3d_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
models = ['lr', 'lasso', 'ridge', 'kr', 'svm', 'knn', 'dt', 'rf', 'gbr']
best = compare_models(sort='RMSE', include=models)
# Out:
# <style type="text/css">
# #T_90682 th {
#   text-align: left;
# }
# ...

# %%
gbr = create_model('gbr')
# Out:
# <style type="text/css">
# #T_31f36_row10_col0, #T_31f36_row10_col1, #T_31f36_row10_col2, #T_31f36_row10_col3, #T_31f36_row10_col4, #T_31f36_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_31f36">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31f36_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_31f36_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_31f36_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_31f36_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_31f36_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_31f36_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
gbr
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=245, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
rf = create_model('rf')
# Out:
# <style type="text/css">
# #T_1f067_row10_col0, #T_1f067_row10_col1, #T_1f067_row10_col2, #T_1f067_row10_col3, #T_1f067_row10_col4, #T_1f067_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_1f067">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f067_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_1f067_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_1f067_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_1f067_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_1f067_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_1f067_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
rf
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=-1, oob_score=False,
#                       random_state=245, verbose=0, warm_start=False)

# %%
dt = create_model('dt')
# Out:
# <style type="text/css">
# #T_2b253_row10_col0, #T_2b253_row10_col1, #T_2b253_row10_col2, #T_2b253_row10_col3, #T_2b253_row10_col4, #T_2b253_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_2b253">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b253_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_2b253_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_2b253_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_2b253_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_2b253_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_2b253_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
dt
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=245, splitter='best')
