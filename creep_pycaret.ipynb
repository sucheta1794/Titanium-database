# %%
import pycaret
import pandas as pd
from pycaret.regression import *
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use(['seaborn'])
from sklearn import set_config
set_config(display='text')

# %%
df = pd.read_csv('creep_pycaret.csv')    # database with standardized features and log-scaled rupture life

# %%
df
# Out:
#      Rupture time (hour)    Al         V        Fe        Mo         N  \
# 0              -1.932929  6.61  4.230000  1.180000  0.657175  0.011000
# 1              -1.515700  6.61  4.230000  1.180000  0.657175  0.011000
# 2              -1.335358  6.61  4.230000  1.180000  0.657175  0.011000
# 3              -1.045757  6.00  4.000000  0.400000  0.657175  0.050000
# 4              -1.018634  6.61  4.230000  1.180000  0.657175  0.011000
# 5              -0.958607  6.00  4.000000  0.400000  0.657175  0.050000
# 6              -0.850781  6.61  4.230000  1.180000  0.657175  0.011000
# 7              -0.769551  6.33  4.000000  0.200000  0.657175  0.010000
# 8              -0.769551  6.61  4.230000  1.180000  0.657175  0.011000
# 9              -0.769551  6.61  4.230000  1.180000  0.657175  0.011000
# 10             -0.721246  5.98  4.070000  0.200000  0.657175  0.005000
# 11             -0.602060  6.33  4.000000  0.200000  0.657175  0.010000
# ...

# %%
# setup the dataset
grid = setup(data=df, target='Rupture time (hour)',train_size=0.9, session_id =234)
# Out:
# <style type="text/css">
# #T_4c720_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4c720">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c720_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4c720_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c720_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4c720_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_4c720_row0_col1" class="data row0 col1" >234</td>
#     </tr>
#     <tr>
#       <th id="T_4c720_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4c720_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4c720_row1_col1" class="data row1 col1" >Rupture time (hour)</td>
#     </tr>
#     <tr>
#       <th id="T_4c720_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
models = [ 'lasso', 'ridge', 'svm', 'knn', 'dt', 'rf',  'gbr']
best = compare_models(sort='RMSE', include=models)
# Out:
# <style type="text/css">
# #T_25bcb th {
#   text-align: left;
# }
# #T_25bcb_row0_col0, #T_25bcb_row0_col1, #T_25bcb_row0_col6, #T_25bcb_row1_col0, #T_25bcb_row1_col2, #T_25bcb_row1_col3, #T_25bcb_row1_col4, #T_25bcb_row1_col5, #T_25bcb_row2_col0, #T_25bcb_row2_col1, #T_25bcb_row2_col2, #T_25bcb_row2_col3, #T_25bcb_row2_col4, #T_25bcb_row2_col5, #T_25bcb_row2_col6, #T_25bcb_row3_col0, #T_25bcb_row3_col1, #T_25bcb_row3_col2, #T_25bcb_row3_col3, #T_25bcb_row3_col4, #T_25bcb_row3_col5, #T_25bcb_row3_col6, #T_25bcb_row4_col0, #T_25bcb_row4_col1, #T_25bcb_row4_col2, #T_25bcb_row4_col3, #T_25bcb_row4_col4, #T_25bcb_row4_col5, #T_25bcb_row4_col6, #T_25bcb_row5_col0, #T_25bcb_row5_col1, #T_25bcb_row5_col2, #T_25bcb_row5_col3, #T_25bcb_row5_col4, #T_25bcb_row5_col5, #T_25bcb_row5_col6, #T_25bcb_row6_col0, #T_25bcb_row6_col1, #T_25bcb_row6_col2, #T_25bcb_row6_col3, #T_25bcb_row6_col4, #T_25bcb_row6_col5, #T_25bcb_row6_col6 {
#   text-align: left;
# }
# ...
